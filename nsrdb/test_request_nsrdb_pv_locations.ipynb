# %%
import requests
import json
import pandas as pd
import numpy as np

from rex import NSRDBX

# %%
network_pv = pd.read_excel("/projects/emco4286/data/ENET39/network.xlsx", sheet_name="PV")
network_eno = pd.read_excel("/projects/emco4286/data/ENET39/network.xlsx", sheet_name="ENO")

network_pv.set_index(network_pv["Name"], inplace=True)
network_eno.set_index(network_eno["Name"], inplace=True)

# %%
data_dir = "/nrel/nsrdb/GOES/aggregated/v4.0.0/"
years = [2014, 2015]

plant_to_year_to_data = {p:{} for p in plant_to_coords.keys()}

for year in years:
    nsrdb_file = os.path.join(data_dir, f"nsrdb_{args.year}.h5")

    with NSRDBX(nsrdb_file, hsds=True) as f:
        for plant, location in plant_to_coords.items()
            for attr in attributes:
                data = f.get_lat_lon_df(attr, location)
                plant_to_data[plant][year][attr] = data
# Out:
# {'QUINEBAUG': (41.76, -72.78),
#  'WALLINGFORD': (41.48, -73.12),
#  'RAVENBROOK': (41.76, -71.17),
#  'CANTON': (42.25, -70.99),
#  'SHAFFER': (42.57, -71.53),
#  'WINSLOW': (44.25, -69.8)}
